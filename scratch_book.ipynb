# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
from datetime import datetime, timedelta
# %matplotlib inline
import yfinance as yf
import mibian as mb

# %%
source_master = Path("Resources/complete_master.csv")
master_df = pd.read_csv(source_master)
source_apple = Path("Resources/master_apple.csv")
source_amd = Path("Resources/master_amd.csv")
source_msft = Path("Resources/master_msft.csv")
source_tsla = Path("Resources/master_tesla.csv")
tsla_df = pd.read_csv(source_tsla)

apple_df = pd.read_csv(source_apple)
amd_df = pd.read_csv(source_amd)
msft_df = pd.read_csv(source_msft)

# %%
# Out:
#    Unnamed: 0                        OptionKey Symbol ExpirationDate  \
# 0      528658  MSFT2019-08-02C124.002019-06-20   MSFT     2019-08-02
# 1      528659  MSFT2019-08-02C125.002019-06-20   MSFT     2019-08-02
# 2      528661  MSFT2019-08-02C127.002019-06-20   MSFT     2019-08-02
# 3      528664  MSFT2019-08-02C130.002019-06-20   MSFT     2019-08-02
# 4      528665  MSFT2019-08-02C131.002019-06-20   MSFT     2019-08-02
#
#    AskPrice  AskSize  BidPrice  BidSize  LastPrice PutCall  StrikePrice  \
# 0     14.60       21     13.85       18      13.79    call        124.0
# 1     13.35       13     12.95        2      12.32    call        125.0
# 2     11.60       13     11.15        3      11.37    call        127.0
# 3      9.05        9      8.85       12       9.15    call        130.0
# 4      8.40       12      8.00       10       7.50    call        131.0
#
#    Volume  OpenInterest  UnderlyingPrice    DataDate
# 0       1             0           136.95  2019-06-20
# ...

# %%
msft_df['ExpirationDate'] =  pd.to_datetime(msft_df['ExpirationDate'], infer_datetime_format=True)
msft_df['DataDate'] =  pd.to_datetime(msft_df['DataDate'], infer_datetime_format=True)
msft_df['time delta'] = msft_df['ExpirationDate'] - msft_df['DataDate']
msft_df['% out'] = msft_df['StrikePrice'] / msft_df['UnderlyingPrice'] - 1

# %%
apple_df['ExpirationDate'] =  pd.to_datetime(apple_df['ExpirationDate'], infer_datetime_format=True)
apple_df['DataDate'] =  pd.to_datetime(apple_df['DataDate'], infer_datetime_format=True)
apple_df['time delta'] = apple_df['ExpirationDate'] - apple_df['DataDate']
apple_df['% out'] = apple_df['StrikePrice'] / apple_df['UnderlyingPrice'] - 1

# %%
amd_df['ExpirationDate'] =  pd.to_datetime(amd_df['ExpirationDate'], infer_datetime_format=True)
amd_df['DataDate'] =  pd.to_datetime(amd_df['DataDate'], infer_datetime_format=True)
amd_df['time delta'] = amd_df['ExpirationDate'] - amd_df['DataDate']
amd_df['% out'] = amd_df['StrikePrice'] / amd_df['UnderlyingPrice'] - 1

# %%
tsla_df['ExpirationDate'] =  pd.to_datetime(tsla_df['ExpirationDate'], infer_datetime_format=True)
tsla_df['DataDate'] =  pd.to_datetime(apple_df['DataDate'], infer_datetime_format=True)
tsla_df['time delta'] = tsla_df['ExpirationDate'] - tsla_df['DataDate']
tsla_df['% out'] = tsla_df['StrikePrice'] / tsla_df['UnderlyingPrice'] - 1

# %%
apple_df.to_csv(r"C:\Users\austi\OneDrive\Desktop\project_2\Resources\apple.csv")
tsla_df.to_csv(r"C:\Users\austi\OneDrive\Desktop\project_2\Resources\tesla.csv")
amd_df.to_csv(r"C:\Users\austi\OneDrive\Desktop\project_2\Resources\amd.csv")
msft_df.to_csv(r"C:\Users\austi\OneDrive\Desktop\project_2\Resources\msft.csv")

# %%
df['exp'] = np.where(df['ExpirationDate'] == df['DataDate'], df.loc['AskPrice'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-29f49afb95f1> in <module>
# ----> 1 df['exp'] = np.where(df['ExpirationDate'] == df['DataDate'], df.loc['AskPrice'])
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'loc'

# %%
tesla = yf.Ticker("TSLA") 
opt = tesla.option_chain('2021-02-19')
opt.calls
# Out:
#           contractSymbol       lastTradeDate  strike  lastPrice     bid  \
# 0    TSLA210219C00200000 2021-01-07 17:43:53   200.0     599.55  679.10
# 1    TSLA210219C00210000 2020-12-31 16:19:37   210.0     505.00  669.10
# 2    TSLA210219C00220000 2020-12-31 15:13:34   220.0     478.57  659.15
# 3    TSLA210219C00230000 2020-12-22 19:58:02   230.0     407.40  649.20
# 4    TSLA210219C00240000 2020-12-30 14:58:30   240.0     434.00  639.25
# ..                   ...                 ...     ...        ...     ...
# 355  TSLA210219C03600000 2020-08-28 16:04:26  3600.0     190.15  160.75
# 356  TSLA210219C03700000 2020-08-27 19:16:13  3700.0     155.21  149.50
# 357  TSLA210219C03800000 2020-08-27 16:26:04  3800.0     163.50  141.50
# 358  TSLA210219C03900000 2020-08-28 16:40:00  3900.0     149.05  129.60
# 359  TSLA210219C04000000 2020-08-28 19:58:45  4000.0     129.04  121.00
#
#         ask     change  percentChange  volume  openInterest  \
# ...

# %%
c = mb.BS([427.53, 300, 0.25, 4], volatility=60)
c = c.asint
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-fe776d0d7197> in <module>
#       1 c = mb.BS([427.53, 300, 0.25, 4], volatility=60)
# ----> 2 c = c.asint
#
# AttributeError: 'BS' object has no attribute 'asint'

# %%
BS([underlyingPrice, strikePrice, interestRate, daysToExpiration], volatility=x, callPrice=y, putPrice=z)

# %%
def my_funcion(column): 
    if column['DataDate'] == column['ExpirationDate'] :
        append 1
